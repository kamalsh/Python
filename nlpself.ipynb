# %%
from bs4 import BeautifulSoup
import urllib.request
import nltk
response = urllib.request.urlopen('http://php.net/')
html = response.read()
soup = BeautifulSoup(html,"html5lib")
text = soup.get_text(strip=False)
tokens = [t for t in text.split()]
freq = nltk.FreqDist(tokens)
for key,val in freq.items():
    print(str(key) + ':' + str(val))
# Out:
# PHP::1
# Hypertext:1
# Preprocessor:1
# Downloads:1
# Documentation:1
# Get:1
# Involved:1
# Help:1
# Getting:1
# Started:1
# Introduction:2
# A:18
# simple:1
# tutorial:1
# Language:2
# Reference:2
# Basic:2
# syntax:1
# Types:1
# Variables:2
# Constants:1
# Expressions:1
# Operators:1
# Control:2
# Structures:1
# Functions:1
# Classes:2
# and:77
# Objects:1
# Namespaces:1
# Errors:1
# Exceptions:2
# Generators:1
# References:1
# Explained:1
# Predefined:3
# Interfaces:1
# Context:1
# options:1
# parameters:1
# Supported:1
# Protocols:1
# Wrappers:1
# Security:4
# General:1
# considerations:1
# Installed:2
# as:2
# CGI:1
# binary:1
# an:2
# Apache:1
# module:1
# Session:2
# Filesystem:1
# Database:3
# Error:1
# Reporting:1
# Using:2
# Register:1
# Globals:1
# User:2
# Submitted:1
# Data:1
# Magic:1
# Quotes:1
# Hiding:1
# PHP:175
# Keeping:1
# Current:1
# Features:1
# HTTP:1
# authentication:1
# with:3
# Cookies:1
# Sessions:1
# Dealing:1
# XForms:1
# Handling:1
# file:19
# ...

# %%
from nltk.tokenize import sent_tokenize
mytext = "Hello Mr. Adam,how are you? S.K. I hope everything is going well . Today is a good day ,see you dude"
print(sent_tokenize(mytext))
# Out:
# ['Hello Mr. Adam,how are you?', 'S.K.', 'I hope everything is going well .', 'Today is a good day ,see you dude']

# %%
from nltk.tokenize import word_tokenize
mytext = "Hello Mr. Adam,how are you? S.K. I hope everything is going well . Today is a good day ,see you dude"
print(word_tokenize(mytext))
# Out:
# ['Hello', 'Mr.', 'Adam', ',', 'how', 'are', 'you', '?', 'S.K', '.', 'I', 'hope', 'everything', 'is', 'going', 'well', '.', 'Today', 'is', 'a', 'good', 'day', ',', 'see', 'you', 'dude']

# %%
from nltk.tokenize import sent_tokenize
mytext = "Bonjour M. Adam,comment allez-vouz? J'espere que tout va bien. Aujourd'hui est un bon jour. "
print(sent_tokenize(mytext,"french"))
# Out:
# ['Bonjour M. Adam,comment allez-vouz?', "J'espere que tout va bien.", "Aujourd'hui est un bon jour."]

# %%
# Synonyms and Antonyms

from nltk.corpus import wordnet
syn = wordnet.synsets('bad')
#print(syn)
print(syn[0].definition())
print(syn[0].examples())
# Out:
# that which is below standard or expectations as of ethics or decency
# ['take the bad with the good']

# %%
from nltk.corpus import wordnet

syn = wordnet.synsets("NLP")
print(syn[0].definition())
syn = wordnet.synsets("Frank")
print(syn[0].definition())
# Out:
# the branch of information science that deals with natural language information
# a member of the ancient Germanic peoples who spread from the Rhine into the Roman Empire in the 4th century

# %%
from nltk.corpus import wordnet
synonyms = []
for syn in wordnet.synsets('good'):
    for lemma in syn.lemmas():
        synonyms.append(lemma.name())
print(synonyms)
# Out:
# ['good', 'good', 'goodness', 'good', 'goodness', 'commodity', 'trade_good', 'good', 'good', 'full', 'good', 'good', 'estimable', 'good', 'honorable', 'respectable', 'beneficial', 'good', 'good', 'good', 'just', 'upright', 'adept', 'expert', 'good', 'practiced', 'proficient', 'skillful', 'skilful', 'good', 'dear', 'good', 'near', 'dependable', 'good', 'safe', 'secure', 'good', 'right', 'ripe', 'good', 'well', 'effective', 'good', 'in_effect', 'in_force', 'good', 'good', 'serious', 'good', 'sound', 'good', 'salutary', 'good', 'honest', 'good', 'undecomposed', 'unspoiled', 'unspoilt', 'good', 'well', 'good', 'thoroughly', 'soundly', 'good']

# %%
from nltk.corpus import wordnet
antonyms = []
for syn in wordnet.synsets('bad'):
    for l in syn.lemmas():
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())
print(antonyms)
# Out:
# ['good', 'goodness', 'good', 'unregretful']
